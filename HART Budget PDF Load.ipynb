# %% [markdown]
# # Scripts to Construct a Historical Archive of Contract Status from Publicly Available Sources
#
# As an experiment in making historical data available for analysis, this notebook is developing some basic tools to extract historical contract status data from publicly available pdf files as well as more recently available excel files. The eventual objective is to construct a complete database with this information for the purposes of analysis.

# %%
#loading libaries
library(pdftools)
library(readxl)

# %% [markdown]
# # Loading a ready Excel File
#
# Note: It looks like this file will need some cleaning up, maybe use a different library to load perhaps the easiest thing to do will be to do a CSV conversion to preserve the dates

# %%
excel_contract_status = read_excel("2018-02 Contract Status Report.xlsx")
colnames(excel_contract_status) = excel_contract_status[1, ] # the first row will be the header
excel_contract_status = excel_contract_status[-1,] 
head(excel_contract_status)
# Out:
#   CPP #  Contract Package Description      Original Contract Value
# 1 DB120  West Oahu/Farrington Hwy Guideway 482430201
# 2 DB320  Kamehameha Hwy Guideway           372150000
# 3 DB200  Maintenance & Storage Facility    195258000
# 4 DB450  Airport Section Guideway/Stations 874750000
# 5 DBB171 West Oahu Station Group           56088470
# 6 DBB271 Farrington Highway Station Group  78999000
#   Change Orders      Current Contract Value Incurred
# 1 186423830.73000002 668854031.73000002     665624607.17000008
# 2 21007573.43        393157573.43000007     391825707.18000001
# 3 86517031.730000019 281775031.73000002     281753402.74999928
# 4 14308.330000000002 874764308.33000004     198641165.52999991
# 5 3521866            59610336               26702756.440000005
# 6 3473034            82472034               44866668.250000015
#   % Exp.              Award Date Original Completion Date
# 1 0.9951717050256137  40128      41568
# 2 0.99661238561836529 40724      41927
# 3 0.99992324025351731 40724      41993
# 4 0.22707964149705984 42633      44317
# 5 0.44795514053133345 42205      43171
# 6 0.54402281687389953 42177      43116
#   Revised\r\nCompletion\r\nDate
# 1 42797
# 2 43008
# 3 42553
# 4 44319
# 5 43171
# 6 43493

# %%
pdfpages <- pdf_text("19A Contract Status_11.16.pdf")

# %%
lines = strsplit(pdfpages, "\n")

# %% [markdown]
# # Converting the PDF to a Data Table in R
#
# This process will involve looking at each page of the PDF one at a time and loading in the text from the tables. It's a manual process now, that should be able to be automated to some extent, but for now, exploring the load manually to get a sense for the ranges of values.
#
# The tables are reasonably well laid out for this type of operation. Columns are fixed width, which means subsets are an effective way to extract individual columns from the text read from the PDF. However the width of the column changes from page to page. These width / breakpoints, can probably be scanned for and established at each page in a future utility.
#
# Some of the rows that are read in are the result of a line wrap from a previous row. These will need to be combined at some point.
#
# Finally, the data rows will need to be isolated. This is currently done manually as well, but can potentially be flagged by end markers (the * footnote that focuses on change orders or the "Totals" row on the last page) and if necessary starting markers (the row of headers).
#
# # First Page Conversion

# %%
pages_by_lines = strsplit(pdfpages, "\n")
first_page_lines = pages_by_lines[[1]]
data_lines = first_page_lines[9:27]
nchar(data_lines)
# Out:
#  [1] 147 147 184 169  60 147 156 183 183 184 157 169 185 169 184 184 184 184 184

# %%
contract = substring(data_lines,1,9)
description = substring(data_lines,10,48)
contractor = substring(data_lines,49,84)
base_value = substring(data_lines,85,99)
change_orders = substring(data_lines,100,113)
current_contract_value = substring(data_lines,114,126)
incurred = substring(data_lines,127,139)
percent_expended = substring(data_lines,140,148)
award_date = substring(data_lines,149,160)
completion_date = substring(data_lines,161,171)

tb = data.frame(contract,
                description,
                contractor,
                base_value,
                change_orders,
                current_contract_value, 
                incurred, 
                percent_expended, 
                award_date, 
                completion_date)
tb
# Out:
#    contract  description
# 1  ART        ART Contracts
# 2  CCH-100    Inactive Hart/City CCH
# 3  CCH-101    HART/ City Dept of BFS
# 4  CCH-102    HART/ City DDC Land Division
# 5
# 6  CCH-107    HART/ City Corporation Counsel (COR)
# 7  CCH-108    HART / Board of Water Supply (BWS)
# 8  DB-120     West Oahu/Farrington Hwy Guideway DB
# 9  DB-200     Maintenance & Storage Facility DB
# 10 DB-320     Kamehameha Hwy Guideway DB
# 11 DB-450     Airport Section Guideway and Sta. DB
# 12 DBB-171    West Oahu Station Group DBB
# 13 DBB-271    Farrington Highway Station Group DBB
# 14 DBB-371    Kamehameha Hwy Stations Grp. DBB
# 15 DBB-385    Ramp H2R2
# 16 DBB-505    Airport Section Utilities Cnstr. DBB
# 17 DBB-525    Airport Section Guideway 7 Pier DBB
# 18 DBOM-920  Core Systems Design Build O/M
# 19 FD-140     West Oahu Station Group FD
#    contractor                           base_value      change_orders
# 1  Multiple Contracts                     $1,098,500               $0
# 2  Multiple Contracts                    $15,348,443               $0
# 3  CCH-Budget & Fiscal Services             $105,092               $0
# 4  CCH-Dept of Design and                   $256,201               $0
# 5  Construction
# 6  Multiple Contracts                     $1,616,253         $250,000
# 7  CCH-Board of Water Supply                $928,325               $0
# 8  Kiewit Infrastructure West Co.       $482,924,000    $166,584,314
# 9  Kiewit Kobayashi a Joint Venture     $195,258,000     $79,600,568
# 10 Kiewit Infrastructure West Co.       $372,150,000     $16,928,661
# 11 Shimmick/Traylor/Granite JV          $875,000,000               $0
# 12 Nan, Inc.                             $56,088,470               $0
# 13 Hawaiian Dredging                     $78,999,000         $955,039
# 14 Nan, Inc.                            $115,805,845               $0
# 15 Royal Contracting                      $5,203,646          $42,522
# 16 Nan, Inc.                             $27,993,290       ($618,741)
# 17 HDCC CJA JV                            $3,973,000          $54,843
# 18 Ansaldo Honolulu Joint Venture       $573,782,793     $26,790,394
# 19 URS Corporation                        $7,789,000      $2,411,643
#    current_contract_value incurred      percent_expended award_date
# 1    $1,098,500                $54,925      5.00
# 2   $15,348,443            $14,925,228     97.24
# 3     $105,092                      $0      0.00         7/1/2011
# 4     $256,201               $173,182      67.60         7/1/2011
# 5
# 6    $1,866,253              $274,606      14.71
# 7     $928,325               $928,325     100.00         7/1/2011
# 8  $649,508,314           $630,631,941     97.09         11/11/2009
# 9  $274,858,568           $274,816,663     99.98         6/30/2011
# 10 $389,078,661           $337,347,099     86.70         6/30/2011
# 11 $875,000,000                 $3,885      0.00         8/12/2016
# 12  $56,088,470             $5,973,930     10.65         7/20/2015
# 13  $79,954,039             $3,473,290      4.34         6/22/2015
# 14 $115,805,845              $646,955       0.56         1/27/2016
# 15   $5,246,168             $1,662,066     31.68         5/18/2015
# 16  $27,374,549            $18,879,924     68.97         6/30/2014
# 17   $4,027,843             $4,027,843    100.00         9/18/2014
# 18 $600,573,187           $243,056,439     40.47         12/9/2011
# 19  $10,200,643             $9,929,537     97.34         6/15/2012
#    completion_date
# 1
# 2
# 3  6/30/2016
# 4  6/30/2016
# 5
# 6
# 7
# 8  10/21/2013
# 9  12/20/2014
# 10 10/15/2014
# 11
# 12 3/12/2018
# 13 12/17/2017
# 14 5/17/2019
# 15 10/2/2016
# 16 2/6/2016
# 17 2/28/2015
# 18 3/15/2019
# 19 11/14/2016

# %% [markdown]
# # Second Page

# %%
second_page_lines = pages_by_lines[[2]]
length(second_page_lines)
nchar(second_page_lines)
data_lines = second_page_lines[9:27]
#data_lines
nchar(data_lines)

contract = substring(data_lines,1,9)
description = substring(data_lines,10,48)
contractor = substring(data_lines,49,84)
base_value = substring(data_lines,85,99)
change_orders = substring(data_lines,100,115)
current_contract_value = substring(data_lines,116,128)
incurred = substring(data_lines,129,141)
percent_expended = substring(data_lines,142,150)
award_date = substring(data_lines,151,160)
completion_date = substring(data_lines,161,172)

tb2 = data.frame(contract,
                description,
                contractor,
                base_value,
                change_orders,
                current_contract_value, 
                incurred, 
                percent_expended, 
                award_date, 
                completion_date)
tb2
# Out:
# [1] 30
#  [1] 100 108 191 145 186 182 185 148 186 186 171 185 186 186 149 149 171 186 185
# [20] 185 172 187 185 158 159 185 170 196 188 176
#  [1] 186 186 171 185 186 186 149 149 171 186 185 185 172 187 185 158 159 185 170
#    contract  description
# 1  FD-240     Farrington Highway Stations Group FD
# 2  FD-340     Kamehameha Hwy Station Group FD
# 3  FD-430     Airport Sect. Guideway/Util FD
# 4  FD-440     Airport Station Group FD
# 5  FD-530     City Center Guideway/Util FD
# 6  FD-550     SPCD - Dillingham and Kaka'ako SG FD
# 7  HRT-200    HART Labor
# 8  HRT-201    HART ODC Contracts
# 9  MI-900     Fare Collection DFI
# 10 MI-930     Elevators & Escalators Install/Maint
# 11 MM-290     Construction Engrg & Insp CEI West
# 12 MM-595     Const. Engrg & Insp. CEI East
# 13 MM-596     Construction Engrg & Insp CEI East 2
# 14 MM-900     Program Mgt Support Conslt (PMSC-1)
# 15 MM-901     Program Mgt Support Conslt (PMSC-2)
# 16 MM-905     MM-905 Gen Engrg Conslt EIS/PE
# 17 MM-910     MM-910 Gen Engrg Conslt FD-Construct
# 18 MM-913     MM-913 Gen Engrg Recompete
# 19 MM-915     HDOT Traffic Mgmt. Consult.
#    contractor                           base_value      change_orders
# 1  URS Corporation                          $9,300,696       $4,994,235
# 2  Anil Verma Associates, Inc.              $8,702,592       $1,257,636
# 3  AECOM Technical Services, Inc.          $38,840,960       $4,293,512
# 4  AECOM Technical Services, Inc.          $10,177,365       $1,396,487
# 5  AECOM Technical Services, Inc.          $43,948,220       $3,149,342
# 6  Perkins+Will                            $18,321,918       $1,309,799
# 7  Multiple Contracts                      $58,451,942               $0
# 8  Multiple Contracts                      $28,239,699        $216,122
# 9  INIT Innovations in Transportation      $15,464,198               $0
# 10 Schindler Elevator Corporation          $50,982,714       $1,069,208
# 11 PGH Wong Engineering, Inc.              $54,232,480               $0
# 12 URS Corporation                         $63,083,417    ($50,377,317)
# 13 Stantec Consulting Services Inc.        $55,036,130               $0
# 14 InfraConsult LLC                        $15,952,569               $0
# 15 InfraConsult LLC                        $33,376,897      $18,444,023
# 16 Parsons Brinckerhoff, Inc.                       $0      $78,564,942
# 17 Parsons Brinckerhoff, Inc.             $150,000,000               $0
# 18 CH2M Hill, Inc                          $46,143,277        $398,451
# 19 ICX Transportation Group, Inc.           $1,600,000       $2,400,000
#    current_contract_value incurred      percent_expended award_date
# 1   $14,294,931            $13,208,066     92.40         1/12/2011
# 2    $9,960,228             $9,784,934     98.24         11/16/2012
# 3   $43,134,472            $41,683,791     96.64         12/22/2011
# 4   $11,573,852            $10,059,820     86.92         11/7/2012
# 5   $47,097,562            $44,431,598     94.34         7/30/2012
# 6   $19,631,717            $12,342,879     62.87         8/8/2013
# 7   $58,451,942            $57,159,803     97.79
# 8   $28,455,821            $26,386,847     92.73
# 9   $15,464,198             $1,187,680      7.68         3/18/2016
# 10  $52,051,922             $6,853,879     13.17         7/31/2013
# 11  $54,232,480            $35,261,239     65.02         1/9/2014
# 12  $12,706,100            $12,382,150     97.45         1/7/2014
# 13  $55,036,130            $10,567,941     19.20         9/10/2015
# 14  $15,952,569                     $0      0.00         11/19/2009
# 15  $51,820,920            $47,860,102     92.36         2/23/2012
# 16  $78,564,942            $74,157,822     94.39         4/8/2011
# 17 $150,000,000           $149,439,999     99.63         6/30/2011
# 18  $46,541,728            $33,984,384     73.02         12/5/2013
# 19   $4,000,000             $3,790,256     94.76         6/5/2012
#    completion_date
# 1    1/15/2012
# 2    2/8/2014
# 3    6/30/2017
# 4    1/27/2014
# 5    4/30/2018
# 6    11/1/2014
# 7
# 8
# 9    1/15/2029
# 10   7/12/2018
# 11   1/9/2020
# 12   1/6/2019
# 13   12/31/2019
# 14   11/18/2012
# 15   2/23/2015
# 16
# 17
# 18   4/4/2019
# 19   6/6/2019

# %% [markdown]
# # Third Page

# %%
third_page_lines = pages_by_lines[[3]]
length(third_page_lines)
nchar(third_page_lines)
data_lines = third_page_lines[9:28]
#data_lines
nchar(data_lines)

contract = substring(data_lines,1,9)
description = substring(data_lines,10,47)
contractor = substring(data_lines,48,84)
base_value = substring(data_lines,85,99)
change_orders = substring(data_lines,100,113)
current_contract_value = substring(data_lines,114,126)
incurred = substring(data_lines,127,141)
percent_expended = substring(data_lines,142,147)
award_date = substring(data_lines,148,158)
completion_date = substring(data_lines,159,172)

tb3 = data.frame(contract,
                description,
                contractor,
                base_value,
                change_orders,
                current_contract_value, 
                incurred, 
                percent_expended, 
                award_date, 
                completion_date)
tb3
# Out:
# [1] 31
#  [1]  98 106 188 142 183 179 182 145 182 168 168 157  61 155  61 183 168 168 168
# [20] 168 167 183 168 168 167 167 168 168 193 185 173
#  [1] 182 168 168 157  61 155  61 183 168 168 168 168 167 183 168 168 167 167 168
# [20] 168
#    contract  description
# 1  MM-920     HDOT Coordination Conslt WOFH
# 2  MM-921     HDOT Coordination Conslt KHG
# 3  MM-922     HDOT Coordination Conslt. Airport
# 4  MM-925     HDOT Labor - WOFH/KHG Agreements
# 5
# 6  MM-930     HDOT State SOA Manager & Consultant
# 7
# 8  MM-935     Real Estate Consultant
# 9  MM-936     Real Estate Consultant II
# 10 MM-937     Real Estate Consultant - Maps/Surv.
# 11 MM-940     Kako'o Consultant
# 12 MM-941     Kako'o Consultant II
# 13 MM-945     On-Call Contractor
# 14 MM-946     On-Call Hazmat Removal Contractor
# 15 MM-947     On-Call Contractor 2
# 16 MM-948     On-call Contractor 3
# 17 MM-950     OCIP Consultant
# 18 MM-951     Owner-Controlled Insurance Program
# 19 MM-960     Archeological & Cultural Monitoring
# 20 MM-962     Core Systems Support
#    contractor                            base_value      change_orders
# 1  AECOM Technical Services, Inc.         $3,000,000        $6,500,000
# 2  AECOM Technical Services, Inc.        $10,000,000      ($1,400,000)
# 3  SSFM International, Inc.              $12,000,000      ($5,600,000)
# 4  Hawaii Department of                     $550,000        $2,865,633
# 5  Transportation
# 6  Hawaii Department of                   $1,272,400         $583,142
# 7  Transportation
# 8  Paragon Partners Ltd.                  $3,000,000        $5,077,665
# 9  Colliers International                 $8,190,000                $0
# 10 R.M. Towill Corporation                $2,998,000                $0
# 11 Pacific Legacy, Inc.                   $1,000,000                $0
# 12 Honua Consulting                         $200,000                $0
# 13 Royal Contracting                      $1,000,000        $1,000,000
# 14 CH2M Hill, Inc                         $3,075,000        $2,075,000
# 15 Royal Contracting                      $7,500,000                $0
# 16 Royal Contracting                     $20,000,000                $0
# 17 Marsh USA Inc.                         $1,250,000                $0
# 18 Aon Risk Services, Inc. of Hawaii     $41,000,000                $0
# 19 Cultural Surveys Hawaii, Inc.          $1,658,474                $0
# 20 Lea + Elliott                         $43,988,989                $0
#    current_contract_value incurred        percent_expended award_date
# 1   $9,500,000             $7,700,551     81.06            6/7/2011
# 2   $8,600,000             $4,872,879     56.66            6/29/2012
# 3   $6,400,000             $3,001,758     46.90            6/8/2012
# 4   $3,415,633             $1,925,497     56.37            10/27/2011
# 5
# 6   $1,855,542              $923,889      49.79            2/3/2012
# 7
# 8   $8,077,665             $7,427,051     91.95            3/14/2012
# 9   $8,190,000                     $0      0.00            9/13/2016
# 10  $2,998,000             $1,634,325     54.51            5/22/2014
# 11  $1,000,000              $537,125      53.71            3/13/2012
# 12   $200,000                 $75,000     37.50            12/8/2015
# 13  $2,000,000             $1,993,482     99.67            8/6/2014
# 14  $5,150,000             $3,401,498     66.05            8/23/2012
# 15  $7,500,000             $7,268,666     96.92            5/21/2015
# 16 $20,000,000             $1,092,388      5.46            5/9/2016
# 17  $1,250,000             $1,163,281     93.06            5/3/2012
# 18 $41,000,000            $36,012,401     87.84            4/9/2014
# 19  $1,658,474             $1,529,264     92.21            1/15/2014
# 20 $43,988,989            $19,868,542     45.17            2/10/2014
#    completion_date
# 1   6/7/2018
# 2   6/30/2017
# 3   6/13/2017
# 4
# 5
# 6
# 7
# 8   3/13/2017
# 9   9/12/2020
# 10  5/21/2017
# 11  3/29/2022
# 12  12/7/2017
# 13  7/6/2019
# 14  8/22/2017
# 15  5/21/2020
# 16  5/16/2023
# 17  5/3/2017
# 18  4/9/2021
# 19  1/24/2019
# 20  9/10/2019

# %% [markdown]
# # Fourth Page

# %%
fourth_page_lines = pages_by_lines[[4]]
length(fourth_page_lines)
nchar(fourth_page_lines)
data_lines = fourth_page_lines[9:18]
total_line = fourth_page_lines[19]
#data_lines
nchar(data_lines)
total_line

contract = substring(data_lines,1,9)
description = substring(data_lines,10,48)
contractor = substring(data_lines,49,84)
base_value = substring(data_lines,85,99)
change_orders = substring(data_lines,100,116)
current_contract_value = substring(data_lines,117,129)
incurred = substring(data_lines,130,146)
percent_expended = substring(data_lines,147,154)
award_date = substring(data_lines,155,164)
completion_date = substring(data_lines,165,176)

tb4 = data.frame(contract,
                description,
                contractor,
                base_value,
                change_orders,
                current_contract_value, 
                incurred, 
                percent_expended, 
                award_date, 
                completion_date)
tb4
# Out:
# [1] 22
#  [1]  98 106 195 150 190 186 189 153 190 176 190 154 163 164 154 191 154 154 153
# [20] 200 192 180
#  [1] 190 176 190 154 163 164 154 191 154 154
# [1] "Total Project:                                                                $3,903,998,079.70   $369,569,216   $4,273,567,295 $2,421,167,243.10   56.65"
#    contract  description
# 1  MM-964     Safety and Security Consultant
# 2  MM-970     Fare Collection Consultant
# 3  MM-975     LEED Commissioning Services for MSF
# 4  MM-980     Construct. Claims and Litigation Svc
# 5  MM-981     Complex Real Property Nego. Lit. Sup
# 6  MM-982     On Call Appraiser
# 7  OTHER      All Project Wide Docs/3P Agreements
# 8  PA-102     Programmatic Agreement HPC
# 9  ROW        Real Estate Docs/ 3P Agreements
# 10 UTIL       Utility Contracts and Agreements
#    contractor                           base_value      change_orders
# 1  Lawson & Associates                    $4,699,573        $232,953
# 2  CH2M Hill, Inc                         $1,178,300               $0
# 3  Enovity, Inc.                            $278,630          $39,900
# 4  Multiple Contracts                       $810,000               $0
# 5  Starn O'Toole Marcus & Fisher            $600,000               $0
# 6  ACM Consultants Inc                    $1,000,000               $0
# 7  Multiple Contracts                       $651,000               $0
# 8  Fung Associates, Inc.                    $400,000               $0
# 9  Multiple Contracts                   $120,885,511               $0
# 10 Multiple Contracts                    $95,637,272     ($1,920,761)
#    current_contract_value incurred          percent_expended award_date
# 1     $4,932,526                $4,330,176     87.79          4/23/2014
# 2     $1,178,300                  $117,787     10.00          9/24/2015
# 3      $318,530                   $254,985     80.05          10/6/2010
# 4      $810,000                    $36,585      4.52
# 5      $600,000                         $0      0.00          9/9/2016
# 6     $1,000,000                        $0      0.00          6/15/2016
# 7      $651,000                   $650,645     99.95
# 8      $400,000                   $197,716     49.43          8/1/2013
# 9   $120,885,511              $119,380,764     98.76
# 10   $93,716,512               $58,421,962     62.34
#    completion_date
# 1    1/31/2017
# 2    12/31/2019
# 3    1/14/2016
# 4
# 5
# 6
# 7
# 8    5/1/2016
# 9
# 10

# %% [markdown]
# # Final Table Loaded From PDF
#
# Note that this needs some cleaning as well, but generally proves the concept. This table has roughly equivalent information to the excel file above. From this a single function that reads in a PDF file into this data frame format can be created to be totally automated or lightly configured.

# %%
contract_status = rbind(tb,tb2,tb3,tb4)
head(contract_status)
# Out:
#   contract  description
# 1 ART        ART Contracts
# 2 CCH-100    Inactive Hart/City CCH
# 3 CCH-101    HART/ City Dept of BFS
# 4 CCH-102    HART/ City DDC Land Division
# 5
# 6 CCH-107    HART/ City Corporation Counsel (COR)
#   contractor                           base_value      change_orders
# 1 Multiple Contracts                     $1,098,500               $0
# 2 Multiple Contracts                    $15,348,443               $0
# 3 CCH-Budget & Fiscal Services             $105,092               $0
# 4 CCH-Dept of Design and                   $256,201               $0
# 5 Construction
# 6 Multiple Contracts                     $1,616,253         $250,000
#   current_contract_value incurred      percent_expended award_date
# 1   $1,098,500                $54,925      5.00
# 2  $15,348,443            $14,925,228     97.24
# 3    $105,092                      $0      0.00         7/1/2011
# 4    $256,201               $173,182      67.60         7/1/2011
# 5
# 6   $1,866,253              $274,606      14.71
#   completion_date
# 1
# 2
# 3 6/30/2016
# 4 6/30/2016
# 5
# 6
